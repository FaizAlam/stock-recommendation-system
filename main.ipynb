# %%
# !pip install PyMYSQL
# Out:
# Requirement already satisfied: PyMYSQL in /opt/anaconda3/lib/python3.9/site-packages (1.0.2)

# %%
import sqlalchemy
import pymysql

# %%
pymysql.install_as_MySQLdb()

# %%
indices = ['Nifty50','RTSI','Bovespa']

# %%
def schema_creator(index):
    engine = sqlalchemy.create_engine('mysql://root:12345678@localhost:3306/')
    engine.execute(sqlalchemy.schema.CreateSchema(index))

# %%
for index in indices:
    schema_creator(index)

# %%
import pandas as pd

# %%
nifty = pd.read_html('https://en.wikipedia.org/wiki/NIFTY_50')[1]
bovespa = pd.read_html('https://en.wikipedia.org/wiki/List_of_companies_listed_on_B3')[0]
rts = pd.read_html('https://en.wikipedia.org/wiki/RTS_Index')[1]

# %%
nifty
# Out:
#                        Company Name      Symbol                      Sector
# 0                       Adani Ports  ADANIPORTS              Infrastructure
# 1                      Asian Paints  ASIANPAINT              Consumer Goods
# 2                         Axis Bank    AXISBANK                     Banking
# 3                        Bajaj Auto  BAJAJ-AUTO                  Automobile
# 4                     Bajaj Finance  BAJFINANCE          Financial Services
# 5                     Bajaj Finserv  BAJAJFINSV          Financial Services
# 6                     Bharti Airtel  BHARTIARTL           Telecommunication
# 7                  Bharat Petroleum        BPCL          Energy - Oil & Gas
# 8              Britannia Industries   BRITANNIA              Consumer Goods
# 9                             Cipla       CIPLA             Pharmaceuticals
# 10                       Coal India   COALINDIA                      Metals
# 11              Divi's Laboratories    DIVISLAB             Pharmaceuticals
# 12         Dr. Reddy's Laboratories     DRREDDY             Pharmaceuticals
# 13                    Eicher Motors   EICHERMOT                  Automobile
# 14                Grasim Industries      GRASIM                      Cement
# 15                 HCL Technologies     HCLTECH      Information Technology
# 16                             HDFC        HDFC          Financial Services
# 17                        HDFC Bank    HDFCBANK                     Banking
# 18                        HDFC Life    HDFCLIFE          Financial Services
# 19                    Hero MotoCorp  HEROMOTOCO                  Automobile
# 20              Hindalco Industries    HINDALCO                      Metals
# 21               Hindustan Unilever  HINDUNILVR              Consumer Goods
# 22                       ICICI Bank   ICICIBANK                     Banking
# 23                    IndusInd Bank  INDUSINDBK                     Banking
# 24                          Infosys        INFY      Information Technology
# 25           Indian Oil Corporation         IOC          Energy - Oil & Gas
# 26                      ITC Limited         ITC              Consumer Goods
# 27                        JSW Steel    JSWSTEEL                      Metals
# 28              Kotak Mahindra Bank   KOTAKBANK                     Banking
# 29                  Larsen & Toubro          LT                Construction
# 30              Mahindra & Mahindra         M&M                  Automobile
# 31                    Maruti Suzuki      MARUTI                  Automobile
# 32                     Nestlé India   NESTLEIND              Consumer Goods
# 33                             NTPC        NTPC              Energy - Power
# 34  Oil and Natural Gas Corporation        ONGC          Energy - Oil & Gas
# 35  Power Grid Corporation of India   POWERGRID              Energy - Power
# 36              Reliance Industries    RELIANCE          Energy - Oil & Gas
# 37              State Bank of India        SBIN                     Banking
# 38       SBI Life Insurance Company     SBILIFE          Financial Services
# 39                    Shree Cements    SHREECEM                      Cement
# 40               Sun Pharmaceutical   SUNPHARMA             Pharmaceuticals
# 41                      Tata Motors  TATAMOTORS                  Automobile
# 42                       Tata Steel   TATASTEEL                      Metals
# 43        Tata Consultancy Services         TCS      Information Technology
# 44           Tata Consumer Products  TATACONSUM              Consumer Goods
# 45                    Tech Mahindra       TECHM      Information Technology
# 46                    Titan Company       TITAN           Consumer Durables
# 47                 UltraTech Cement  ULTRACEMCO                      Cement
# 48        United Phosphorus Limited         UPL                   Chemicals
# 49                            Wipro       WIPRO  Information Technology[14]

# %%
nifty = nifty.Symbol.to_list()
nifty
# Out:
# ['ADANIPORTS',
#  'ASIANPAINT',
#  'AXISBANK',
#  'BAJAJ-AUTO',
#  'BAJFINANCE',
#  'BAJAJFINSV',
#  'BHARTIARTL',
#  'BPCL',
#  'BRITANNIA',
#  'CIPLA',
#  'COALINDIA',
#  'DIVISLAB',
#  'DRREDDY',
#  'EICHERMOT',
#  'GRASIM',
#  'HCLTECH',
#  'HDFC',
#  'HDFCBANK',
#  'HDFCLIFE',
#  'HEROMOTOCO',
#  'HINDALCO',
#  'HINDUNILVR',
#  'ICICIBANK',
#  'INDUSINDBK',
#  'INFY',
#  'IOC',
#  'ITC',
#  'JSWSTEEL',
#  'KOTAKBANK',
#  'LT',
#  'M&M',
#  'MARUTI',
#  'NESTLEIND',
#  'NTPC',
#  'ONGC',
#  'POWERGRID',
#  'RELIANCE',
#  'SBIN',
#  'SBILIFE',
#  'SHREECEM',
#  'SUNPHARMA',
#  'TATAMOTORS',
#  'TATASTEEL',
#  'TCS',
#  'TATACONSUM',
#  'TECHM',
#  'TITAN',
#  'ULTRACEMCO',
#  'UPL',
#  'WIPRO']

# %%
bovespa
# Out:
#             Company Ticker                  Industry        Headquarters
# 0   Alpargatas [pt]  ALPA4                  clothing           São Paulo
# 1             Ambev  ABEV3                 beverages           São Paulo
# 2        Americanas  AMER3             online retail      Rio de Janeiro
# 3              Azul  AZUL4                  airlines             Barueri
# 4                B3  B3SA3            stock exchange           São Paulo
# ..              ...    ...                       ...                 ...
# 85         Usiminas  USIM5  siderurgy and metallurgy      Belo Horizonte
# 86             Vale  VALE3                    mining      Rio de Janeiro
# 87              Via  VIIA3                    retail  São Caetano do Sul
# 88            YDUQS  YDUQ3          higher education      Rio de Janeiro
# 89              WEG  WEGE3    industrial engineering      Jaraguá do Sul
#
# [90 rows x 4 columns]

# %%
bovespa = bovespa.Ticker.to_list()

# %%
rts
# Out:
#                               Company Ticker symbol  \
# 0                         AFK Sistema          AFKS
# 1                            Aeroflot          AFLT
# 2                             Rusagro          AGRO
# 3                               Acron          AKRN
# 4                               Lenta          LNTA
# 5               Credit Bank of Moscow          CBOM
# 6                          Detsky Mir          DSKY
# 7                           SeverStal          CHMF
# 8                                DIXY          DIXY
# 9                             FGC UES          FEES
# 10                            Gazprom          GAZP
# 11                     Norilsk Nickel          GMKN
# 12                           RusHydro          HYDR
# 13                          Inter RAO          IRAO
# 14                             Lukoil          LKOH
# 15                          LSR Group          LSRG
# 16  Magnitogorsk Iron and Steel Works          MAGN
# 17                            MegaFon          MFON
# 18                        OJSC Magnit          MGNT
# 19                    Moscow Exchange          MOEX
# 20                          Mosenergo          MSNG
# 21                             Mechel          MTLR
# 22                             Alrosa          ALRS
# 23                 Mobile TeleSystems          MTSS
# 24                            M.video          MVID
# 25                  Novolipetsk Steel          NLMK
# 26   Novorossiysk Commercial Sea Port          NMPT
# 27                            Novatek          NVTK
# 28                           PhosAgro          PHOR
# 29                          PIK Group          PIKK
# 30                        Polyus Gold          PLZL
# 31            Polymetal International          POLY
# 32                            Rosneft          ROSN
# 33                            Rosseti          RSTI
# 34                         Rostelecom          RTKM
# 35                              Rusal         RUALR
# 36                                SFI          EPLN
# 37                           Sberbank          SBER
# 38                           Sberbank         SBERP
# 39                     Surgutneftegas          SNGS
# 40                     Surgutneftegas         SNGSP
# 41                            Tatneft          TATN
# 42                            Tatneft         TATNP
# 43                            OAO TMK          TRMK
# 44                          Transneft         TRNFP
# 45                             Unipro          UPRO
# 46                           Russneft          RNFT
# 47               United Wagon Company          UWGN
# 48                           VTB Bank          VTBR
# 49                             Yandex          YNDX
#
#                           Stock type                 Industry
# 0                             Common             Conglomerate
# 1                             Common           Transportation
# 2                 Depositary receipt              Agriculture
# 3                             Common                Chemicals
# 4                 Depositary receipt                   Retail
# 5                             Common                  Banking
# 6                             Common                   Retail
# 7                             Common      Mining & Metallurgy
# 8                             Common                   Retail
# 9                             Common         Electric utility
# 10                            Common                Oil & gas
# 11                            Common      Mining & Metallurgy
# 12                            Common                   Energy
# 13                            Common                   Energy
# 14                            Common                Oil & gas
# 15                            Common  Real estate development
# 16                            Common               Metallurgy
# 17                            Common        Telecommunication
# 18                            Common                   Retail
# 19                            Common           Stock exchange
# 20                            Common                   Energy
# 21                            Common      Mining & Metallurgy
# 22                            Common                   Mining
# 23                            Common        Telecommunication
# 24                            Common                   Retail
# 25                            Common               Metallurgy
# 26                            Common           Transportation
# 27                            Common                Oil & gas
# 28                            Common                Chemicals
# 29                            Common  Real estate development
# 30                            Common                   Mining
# 31                            Common                   Mining
# 32                            Common                Oil & gas
# 33                            Common         Electric utility
# 34                            Common        Telecommunication
# 35  Russian depositary receipt (RDR)                   Mining
# 36                            Common                  Leasing
# 37                            Common                  Banking
# 38                         Preferred                  Banking
# 39                            Common                Oil & gas
# 40                         Preferred                Oil & gas
# 41                            Common                Oil & gas
# 42                         Preferred                Oil & gas
# 43                            Common           Steel industry
# 44                         Preferred                Oil & gas
# 45                            Common         Electric utility
# 46                            Common                 Refining
# 47                            Common   Mechanical engineering
# 48                            Common                  Banking
# 49                            Common                 Internet

# %%
rts = rts['Ticker symbol'].to_list()

# %%
bovespa = [i +'.SA' for i in bovespa]
bovespa
# Out:
# ['ALPA4.SA',
#  'ABEV3.SA',
#  'AMER3.SA',
#  'AZUL4.SA',
#  'B3SA3.SA',
#  'BBAS3.SA',
#  'BBSE3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BIDI11.SA',
#  'BPAN4.SA',
#  'BRAP4.SA',
#  'BRML3.SA',
#  'BRKM5.SA',
#  'BRFS3.SA',
#  'BPAC11.SA',
#  'CRFB3.SA',
#  'CCRO3.SA',
#  'CVCB3.SA',
#  'CMIG4.SA',
#  'CIEL3.SA',
#  'COGN3.SA',
#  'CPLE6.SA',
#  'CSAN3.SA',
#  'CPFE3.SA',
#  'CSNA3.SA',
#  'CYRE3.SA',
#  'DXCO3.SA',
#  'ECOR3.SA',
#  'ENBR3.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'EMBR3.SA',
#  'ENGI11.SA',
#  'ENEV3.SA',
#  'EGIE3.SA',
#  'EQTL3.SA',
#  'EZTC3.SA',
#  'GGBR4.SA',
#  'GOLL4.SA',
#  'PCAR3.SA',
#  'SOMA3.SA',
#  'FLRY3.SA',
#  'HAPV3.SA',
#  'HYPE3.SA',
#  'IGTA3.SA',
#  'GNDI3.SA',
#  'IRBR3.SA',
#  'ITUB4.SA',
#  'ITSA4.SA',
#  'JBSS3.SA',
#  'JHSF3.SA',
#  'KLBN11.SA',
#  'RENT3.SA',
#  'LWSA3.SA',
#  'LAME4.SA',
#  'LREN3.SA',
#  'MGLU3.SA',
#  'MRFG3.SA',
#  'CASH3.SA',
#  'GOAU4.SA',
#  'BEEF3.SA',
#  'MRVE3.SA',
#  'MULT3.SA',
#  'NTCO3.SA',
#  'PETR3.SA',
#  'PETR4.SA',
#  'BRDT3.SA',
#  'PRIO3.SA',
#  'PETZ3.SA',
#  'QUAL3.SA',
#  'RADL3.SA',
#  'RDOR3.SA',
#  'RAIL3.SA',
#  'SBSP3.SA',
#  'SANB11.SA',
#  'ASAI3.SA',
#  'SULA11.SA',
#  'SUZB3.SA',
#  'TAEE11.SA',
#  'VIVT3.SA',
#  'TIMS3.SA',
#  'TOTS3.SA',
#  'UGPA3.SA',
#  'LCAM3.SA',
#  'USIM5.SA',
#  'VALE3.SA',
#  'VIIA3.SA',
#  'YDUQ3.SA',
#  'WEGE3.SA']

# %%
nifty = [i +'.NS' for i in nifty]
rts = [i +'.ME' for i in rts]

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.69-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy>=1.15 in /opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.20.3)
# Requirement already satisfied: requests>=2.26 in /opt/anaconda3/lib/python3.9/site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: pandas>=0.24 in /opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.3.4)
# Requirement already satisfied: lxml>=4.5.1 in /opt/anaconda3/lib/python3.9/site-packages (from yfinance) (4.6.3)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.10.tar.gz (8.2 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24->yfinance) (2021.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (3.2)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8500 sha256=604ff831bff97fff46d5a80388d34307cc25edd721041a7afa2f5cdc54213569
#   Stored in directory: /Users/faizalaam/Library/Caches/pip/wheels/f2/b5/2c/59ba95dcf854e542944c75fe3da584e4e3833b319735a0546c
# Successfully built multitasking
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.10 yfinance-0.1.69

# %%
import yfinance as yf

# %%
yf.download(nifty[0],start='2022-01-15')
# Out:
# [*********************100%***********************]  1 of 1 completed
#               Open        High         Low       Close   Adj Close   Volume
# Date
# 2022-01-17  783.50  789.400024  773.900024  779.049988  779.049988  3187871
# 2022-01-18  780.00  790.000000  760.000000  762.950012  762.950012  4300929
# 2022-01-19  761.75  761.750000  736.000000  744.200012  744.200012  5843870
# 2022-01-20  744.00  751.700012  735.000000  738.000000  738.000000  4739602

# %%
mapper = {'Nifty50':nifty,'Bovespa':bovespa,"RTSI":rts}

# %%
for index in indices:
    engine = sqlalchemy.create_engine('mysql://root:12345678@localhost:3306/'+index)
    for symbol in mapper[index]:
        df = yf.download(symbol, start='2021-01-01')
        df = df.reset_index()
        df.to_sql(symbol,engine)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MFON.ME: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - NMPT.ME: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - RUALR.ME: No data found for this date range, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EPLN.ME: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BRDT3.SA: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
